# %% [markdown]
# ##### Suma

# %%
sumar = 2.0 + 5
seguir_sumando = sumar + 8
print(seguir_sumando)
# Out:
# 15.0

# %% [markdown]
# ##### Resta

# %%
restar = 120 - 0
seguir_restando = restar - 20
print(seguir_restando)
# Out:
# 100

# %% [markdown]
# ##### Multiplicación

# %%
multi = 3 * 4.5
print(multi)
# Out:
# 13.5

# %% [markdown]
# ##### Exponenciación

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ##### División

# %%
print(33/2)
# Out:
# 16.5

# %% [markdown]
# ##### División entera

# %%
print(33//2)
# Out:
# 16

# %% [markdown]
# ##### Módulo

# %%
print(45%6)
# Out:
# 3
